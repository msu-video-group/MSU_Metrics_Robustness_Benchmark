# %% [markdown]
# Demo for MANIQA metric setup

# %%
# Run theese commands in benchmark's root directory to setup MANIQA metric from it's source directory.
# You can also use your custom metric if it matches framework's call interface. An example implementation can be found in the model.py file in subjects/maniqa/

# !git submodule update --init --recursive
# !cd subjects/maniqa/src && git apply ../patches/maniqa.patch -v
# !cd subjects/maniqa && cp model.py src

# %%
# Load MANIQA weights
# !wget https://github.com/IIGROUP/MANIQA/releases/download/Koniq10k/ckpt_koniq10k.pt -P subjects/maniqa/
# Install MANIQA requirements
# !pip install -r subjects/maniqa/src/requirements.txt

# %%
# Change these parameters if you are using other metric. 
# 'bounds' in metric_cfg specify minimum and maximum possible metric values if such limits exist, approximate range of metric's values otherwise.
metric_path = './subjects/maniqa/src/'
path_to_weights = './subjects/maniqa/ckpt_koniq10k.pt'
metric_cfg = {'is_fr': False, 'bounds':{'low':0, 'high':1}, 'name':'maniqa'}
device = 'cuda:0'

# %%
import sys
sys.path.append(metric_path)
from model import MetricModel

# %%
model = MetricModel(model_path=path_to_weights, device=device)

# %% [markdown]
# Run benchmark attacks

# %%
import robustness_benchmark as rb

# %%
# Specify path to dataset and it's name. It must be a directory containing only images (or only videos)
dataset_path = './test_dataset/'
dataset_name = 'TEST'

# Specify directory where results of attacks will be stored. 
# Results will be organized as directories with names similar to the attacks.
# Files with names *metric_name*.csv will be saved in these directories.
result_save_dir = './test_results/'

# attacks_to_run = rb.interface.iterative_attacks
# attacks_to_run = rb.interface.uap_attacks
attacks_to_run = rb.interface.all_default_attacks
rb.interface.all_default_attacks.keys()
# Out:
# dict_keys(['ifgsm', 'mifgsm', 'amifgsm', 'std-fgsm', 'korhonen-et-al', 'madc', 'cumulative-uap', 'generative-uap', 'uap'])

# %%
# You can also add your custom attack 
# Make sure that it follows benchmark call interface.
# You can find default attacks implementation in robustness_benchmark.methods.<attack name>
# attacks_to_run['attack name'] = <attack callable>

# %%
# Results saved in this notebook's cell outputs are not representative, attacks were launched on small debug set of only 5 images.
rb.interface.run_attacks(
                        attacks_dict=attacks_to_run,
                        device=device, 
                        metric_model=model, 
                        metric_cfg=metric_cfg, 
                        dataset_names=[dataset_name], 
                        dataset_paths=[dataset_path], 
                        save_dir=result_save_dir)

# %% [markdown]
# Collect results from csv files

# %%
results_df = rb.interface.collect_results(result_save_dir, metric_cfg=metric_cfg)
results_df
# Out:
#    dataset  maniqa_clear  maniqa_attacked  maniqa_ssim  maniqa_psnr  \
# 0     TEST      0.497564         1.108695     0.809924    30.214003
# 1     TEST      0.568488         1.090278     0.906829    29.778993
# 2     TEST      0.335649         1.060856     0.812977    30.184957
# 3     TEST      0.510699         1.091831     0.793638    30.128886
# 4     TEST      0.485868         0.956575     0.905383    29.416244
# ..     ...           ...              ...          ...          ...
# 47    TEST      0.497564         0.313744     0.567957    24.812781
# 50    TEST      0.568488         0.353059     0.783253    24.812781
# 53    TEST      0.335649         0.202528     0.578624    24.812781
# 56    TEST      0.510699         0.289065     0.572215    24.812781
# 59    TEST      0.485868         0.338082     0.799441    24.812781
#
#     maniqa_mse                      attack
# 0     0.000952                     amifgsm
# 1     0.001052                     amifgsm
# 2     0.000958                     amifgsm
# 3     0.000971                     amifgsm
# 4     0.001144                     amifgsm
# ..         ...                         ...
# 47    0.003302  default-uap_VOC2012_amp0.8
# 50    0.003302  default-uap_VOC2012_amp0.8
# 53    0.003302  default-uap_VOC2012_amp0.8
# 56    0.003302  default-uap_VOC2012_amp0.8
# 59    0.003302  default-uap_VOC2012_amp0.8
#
# [285 rows x 7 columns]

# %% [markdown]
# Domain transformation

# %% [markdown]
# Note: domain transformation (based on Neural Optimal Transport, described ) currently only works with metrics used in benchmark, for which domain transformation is pretrained and stored in ```robustness_benchmark/models/models_to_mdtvsfa.pth```.\
# For other metrics, you can still use ```evaluate_robustness()``` on results_df.

# %%
transformed_results_df = rb.interface.domain_transform(results_df, metrics=[metric_cfg['name']], batch_size=1000, device=device)
transformed_results_df
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12.58it/s]
# current metric:  maniqa
#    dataset  maniqa_clear  maniqa_attacked  maniqa_ssim  maniqa_psnr  \
# 0     TEST      0.593020         1.385626     0.809924    30.214003
# 1     TEST      0.691731         1.360014     0.906829    29.778993
# 2     TEST      0.316637         1.326889     0.812977    30.184957
# 3     TEST      0.605928         1.363978     0.793638    30.128886
# 4     TEST      0.571077         1.199576     0.905383    29.416244
# ..     ...           ...              ...          ...          ...
# 47    TEST      0.593067         0.286116     0.567957    24.812781
# 50    TEST      0.699335         0.339540     0.783253    24.812781
# 53    TEST      0.321193         0.115863     0.578624    24.812781
# 56    TEST      0.616140         0.231154     0.572215    24.812781
# 59    TEST      0.572159         0.319131     0.799441    24.812781
#
#     maniqa_mse                      attack
# 0     0.000952                     amifgsm
# 1     0.001052                     amifgsm
# 2     0.000958                     amifgsm
# 3     0.000971                     amifgsm
# 4     0.001144                     amifgsm
# ..         ...                         ...
# 47    0.003302  default-uap_VOC2012_amp0.8
# 50    0.003302  default-uap_VOC2012_amp0.8
# 53    0.003302  default-uap_VOC2012_amp0.8
# 56    0.003302  default-uap_VOC2012_amp0.8
# 59    0.003302  default-uap_VOC2012_amp0.8
#
# [285 rows x 7 columns]

# %% [markdown]
# Metric robustness evaluation

# %%
# W/o domain transformation
# rb.interface.evaluate_robustness(results_df, attacks=list(transformed_results_df.attack.unique()) + ['all', 'iterative', 'uap'])

rb.interface.evaluate_robustness(transformed_results_df, attacks=list(transformed_results_df.attack.unique()) + ['all', 'iterative', 'uap'])
# Out:
#     metric                         attack energy_distance_score  \
# 0   maniqa                        amifgsm                 1.879
# 1   maniqa     cumulative-uap_COCO_amp0.2                -0.063
# 2   maniqa  cumulative-uap_VOC2012_amp0.2                -0.325
# 3   maniqa     cumulative-uap_COCO_amp0.4                -0.187
# 4   maniqa  cumulative-uap_VOC2012_amp0.4                -0.654
# 5   maniqa     cumulative-uap_COCO_amp0.8                -0.253
# 6   maniqa  cumulative-uap_VOC2012_amp0.8                -1.083
# 7   maniqa     generative-uap_COCO_amp0.2                -0.112
# 8   maniqa  generative-uap_VOC2012_amp0.2                -0.107
# 9   maniqa     generative-uap_COCO_amp0.4                -0.241
# 10  maniqa  generative-uap_VOC2012_amp0.4                -0.300
# 11  maniqa     generative-uap_COCO_amp0.8                -0.437
# 12  maniqa  generative-uap_VOC2012_amp0.8                -0.581
# 13  maniqa                          ifgsm                 2.151
# 14  maniqa                 korhonen-et-al                 1.887
# 15  maniqa                           madc                 0.988
# 16  maniqa                         mifgsm                 1.875
# 17  maniqa                       std-fgsm                 1.142
# 18  maniqa        default-uap_COCO_amp0.2                -0.267
# 19  maniqa     default-uap_VOC2012_amp0.2                -0.303
# 20  maniqa        default-uap_COCO_amp0.4                -0.585
# 21  maniqa     default-uap_VOC2012_amp0.4                -0.627
# 22  maniqa        default-uap_COCO_amp0.8                -0.985
# 23  maniqa     default-uap_VOC2012_amp0.8                -1.005
# 24  maniqa                            all                 0.574
# 25  maniqa                      iterative                 1.581
# 26  maniqa                            uap                -0.390
#
#    normalized_absolute_gain normalized_relative_gain    relative_gain_classic  \
# 0      2.016 (1.848, 2.184)     1.364 (1.055, 1.674)     1.563 (1.171, 1.956)
# 1   -0.011 (-0.021, -0.001)  -0.007 (-0.012, -0.001)  -0.007 (-0.013, -0.001)
# 2   -0.163 (-0.229, -0.096)  -0.099 (-0.134, -0.064)  -0.112 (-0.150, -0.074)
# 3   -0.057 (-0.093, -0.022)  -0.034 (-0.053, -0.014)  -0.038 (-0.059, -0.016)
# 4   -0.440 (-0.532, -0.349)  -0.276 (-0.328, -0.224)  -0.315 (-0.379, -0.252)
# 5    -0.051 (-0.138, 0.037)   -0.016 (-0.082, 0.050)   -0.015 (-0.093, 0.063)
# 6   -0.856 (-1.003, -0.709)  -0.525 (-0.564, -0.486)  -0.589 (-0.633, -0.545)
# 7   -0.034 (-0.050, -0.018)  -0.022 (-0.034, -0.011)  -0.025 (-0.038, -0.012)
# 8   -0.034 (-0.060, -0.008)  -0.023 (-0.039, -0.007)  -0.026 (-0.045, -0.008)
# 9   -0.106 (-0.156, -0.057)  -0.066 (-0.093, -0.039)  -0.074 (-0.105, -0.043)
# 10  -0.142 (-0.210, -0.074)  -0.087 (-0.125, -0.050)  -0.099 (-0.140, -0.057)
# 11  -0.272 (-0.405, -0.138)  -0.166 (-0.238, -0.095)  -0.185 (-0.265, -0.106)
# 12  -0.340 (-0.458, -0.223)  -0.198 (-0.255, -0.140)  -0.220 (-0.281, -0.159)
# 13     2.965 (2.470, 3.459)     2.011 (1.484, 2.538)     2.308 (1.656, 2.960)
# 14     2.040 (1.849, 2.231)     1.374 (1.016, 1.733)     1.599 (1.131, 2.068)
# 15     0.776 (0.671, 0.882)     0.529 (0.369, 0.689)     0.611 (0.408, 0.813)
# 16     2.006 (1.838, 2.174)     1.360 (1.050, 1.670)     1.565 (1.169, 1.960)
# 17     0.935 (0.793, 1.078)     0.640 (0.445, 0.836)     0.739 (0.492, 0.985)
# 18  -0.128 (-0.190, -0.067)  -0.081 (-0.116, -0.045)  -0.091 (-0.131, -0.051)
# 19  -0.151 (-0.215, -0.087)  -0.092 (-0.125, -0.058)  -0.104 (-0.141, -0.067)
# 20  -0.389 (-0.491, -0.286)  -0.247 (-0.316, -0.179)  -0.284 (-0.368, -0.200)
# 21  -0.421 (-0.523, -0.319)  -0.265 (-0.328, -0.203)  -0.302 (-0.377, -0.226)
# 22  -0.761 (-0.888, -0.635)  -0.470 (-0.517, -0.422)  -0.531 (-0.592, -0.470)
# 23  -0.781 (-0.913, -0.649)  -0.482 (-0.527, -0.437)  -0.545 (-0.602, -0.487)
# 24     0.502 (0.364, 0.640)     0.351 (0.250, 0.451)     0.412 (0.292, 0.532)
# 25     1.846 (1.673, 2.019)     1.251 (1.089, 1.412)     1.457 (1.256, 1.658)
# 26  -0.281 (-0.323, -0.239)  -0.173 (-0.198, -0.147)  -0.198 (-0.227, -0.169)
#
#            robustness_score wasserstein_score
# 0   -0.387 (-0.422, -0.351)             2.016
# 1      2.101 (1.594, 2.609)            -0.012
# 2      0.766 (0.567, 0.966)            -0.163
# 3      1.289 (1.010, 1.567)            -0.057
# 4      0.284 (0.183, 0.385)            -0.440
# 5      0.960 (0.760, 1.160)            -0.108
# 6    -0.007 (-0.126, 0.112)            -0.856
# 7      1.518 (1.231, 1.806)            -0.034
# 8      1.413 (1.130, 1.696)            -0.034
# 9      1.043 (0.706, 1.379)            -0.106
# 10     0.872 (0.605, 1.139)            -0.142
# 11     0.735 (0.235, 1.236)            -0.272
# 12     0.455 (0.210, 0.700)            -0.340
# 13  -0.535 (-0.604, -0.465)             2.965
# 14  -0.392 (-0.436, -0.349)             2.040
# 15    0.035 (-0.017, 0.086)             0.776
# 16  -0.386 (-0.423, -0.350)             2.006
# 17   -0.042 (-0.120, 0.037)             0.935
# 18     0.927 (0.650, 1.203)            -0.128
# 19     0.797 (0.611, 0.984)            -0.151
# 20     0.348 (0.249, 0.448)            -0.389
# 21     0.310 (0.211, 0.409)            -0.421
# 22    0.045 (-0.049, 0.140)            -0.761
# 23    0.032 (-0.066, 0.130)            -0.781
# 24     0.379 (0.291, 0.466)             0.691
# 25  -0.303 (-0.347, -0.260)             1.846
# 26     0.776 (0.679, 0.873)            -0.281
